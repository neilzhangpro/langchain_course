# %% [markdown]
# ## AI Agent智能应用从0到1定制开发
# ## AI Agent Intelligent Application Custom Development from 0 to 1
# ******
# - 此代码为网课《AI Agent智能应用从0到1定制开发》的配套代码，需要注意本套代码建议与网课适配配合食用。
# - This code for the online course <AI Agent Intelligent Applications from 0 to 1 custom development> supporting code, need to pay attention to this set of code is recommended with the online course adapted to work with consumption.
# - 需要注意由于课程开发周期的原因，langchain版本跨越了3个大版本，部分代码会与视频演示有差别!
# - Note that due to the course development cycle, the langchain version spans 3 major releases and some of the code will differ from the video demo!
# - 课程地址：https://coding.imooc.com/class/822.html
# - Course address: https://coding.imooc.com/class/822.html

# %% [markdown]
# ### 从环境变量中读取密钥
# ### Read the key from the environment variable
# - 注意：尽量将你的OpenAI Key存储在类似.env文件中，而不是明文暴露在代码里，这是一种基本的安全措施
# - Note: Try to store your OpenAI Key in something like an .env file, rather than exposing it explicitly in code, as a basic safety measure!
# ******

# %%
import os
from dotenv import load_dotenv
# Load environment variables from openai.env file
load_dotenv("asset/openai.env")

# Read the OPENAI_API_KEY from the environment
api_key = os.getenv("OPENAI_API_KEY")
api_base = os.getenv("OPENAI_API_BASE")
os.environ["OPENAI_API_KEY"] = api_key
os.environ["OPENAI_API_BASE"] = api_base
os.environ["SERPAPI_API_KEY"] = os.getenv("SERPAPI_API_KEY")
os.environ["ELEVEN_API_KEY"] = os.getenv("ELEVEN_API_KEY")
os.environ["AZURE_COGS_KEY"] = os.getenv("AZURE_COGS_KEY")
os.environ["AZURE_COGS_ENDPOINT"] = os.getenv("AZURE_COGS_ENDPOINT")
os.environ["AZURE_COGS_REGION"] = os.getenv("AZURE_COGS_REGION")
os.environ["DASHSCOPE_API_KEY"] = os.getenv("DASHSCOPE_API_KEY")
os.environ["ZHIPUAI_API_KEY"] = os.getenv("ZHIPUAI_API_KEY")
zhipukey =  os.getenv("ZHIPUAI_API_KEY")
os.environ["TAVILY_API_KEY"] = os.getenv("TAVILY_API_KEY")
os.environ["MOONSHOT_API_KEY"] = os.getenv("MoonShot_key")
MoonShot_key = os.getenv("MoonShot_key")
os.environ["BAICHUAN_API_KEY"] = os.getenv("BAICHUAN_API_KEY")

# %% [markdown]
# ### Langgraph 时光旅行
# ### Langgraph Time travel
# ******

# %%
from typing_extensions import TypedDict
from typing import Annotated, Literal
from langgraph.graph.message import add_messages
from langchain_core.tools import tool
from langgraph.prebuilt import ToolNode
from langchain_community.chat_models import ChatZhipuAI
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.sqlite import SqliteSaver
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.messages import HumanMessage, AIMessage

# Add messages essentially does this with more robust handling
# def add_messages(left: list, right: list):
#     return left + right


class State(TypedDict):
    messages: Annotated[list, add_messages]


@tool
def search(query: str):
    """Call to surf the web."""
    # This is a placeholder for the actual implementation
    return ["The weather is cloudy with a chance of meatballs."]


tools = [search]
tool_node = ToolNode(tools)

# We will set streaming=True so that we can stream tokens
# See the streaming section for more information on this.
model = ChatZhipuAI(
    model="GLM-4-Plus",
    temperature=0
)

model = model.bind_tools(tools)


# Define the function that determines whether to continue or not
def should_continue(state: State) -> Literal["continue", "end"]:
    last_message = state["messages"][-1]
    # If there is no function call, then we finish
    if not last_message.tool_calls:
        return "end"
    # Otherwise if there is, we continue
    else:
        return "continue"


def call_model(state: State):
    response = model.invoke(state["messages"])
    # We return a list, because this will get added to the existing list
    return {"messages": response}


# Define a new graph
workflow = StateGraph(State)

# Define the two nodes we will cycle between
workflow.add_node("agent", call_model)
workflow.add_node("action", tool_node)

# Set the entrypoint as `agent`
# This means that this node is the first one called
workflow.set_entry_point("agent")

# We now add a conditional edge
workflow.add_conditional_edges(
    # First, we define the start node. We use `agent`.
    # This means these are the edges taken after the `agent` node is called.
    "agent",
    # Next, we pass in the function that will determine which node is called next.
    should_continue,
    # Finally we pass in a mapping.
    # The keys are strings, and the values are other nodes.
    # END is a special node marking that the graph should finish.
    # What will happen is we will call `should_continue`, and then the output of that
    # will be matched against the keys in this mapping.
    # Based on which one it matches, that node will then be called.
    {
        # If `tools`, then we call the tool node.
        "continue": "action",
        # Otherwise we finish.
        "end": END,
    },
)

# We now add a normal edge from `tools` to `agent`.
# This means that after `tools` is called, `agent` node is called next.
workflow.add_edge("action", "agent")

#memory = SqliteSaver.from_conn_string(":memory:")
memory = MemorySaver()
print(memory)
# Finally, we compile it!
# This compiles it into a LangChain Runnable,
# meaning you can use it as you would any other runnable
app = workflow.compile(checkpointer=memory)


def main():
    nowStats = {}
    config = {"configurable": {"thread_id": "2"}}
    input_message = HumanMessage(content="hi! I'm bob")
    for event in app.stream({"messages": [input_message]},
                            config,
                            stream_mode="values"):
        event["messages"][-1].pretty_print()

    #获取状态
    nowStats = app.get_state(config).values
    print(nowStats)
    #获取下一步状态
    nowStats = app.get_state(config).next
    print(nowStats)

    #执行工具
    config = {"configurable": {"thread_id": "2"}}
    input_message = HumanMessage(content="what is the weather in sf currently")
    for event in app.stream({"messages": [input_message]},
                            config,
                            stream_mode="values"):
        event["messages"][-1].pretty_print()

    print(
        "************************************thread_id:4*****************************************************"
    )
    #重新定义工作流，注意增加了interrupt_before参数 这意味着在采取任何操作之前我们会暂停，人类可以在这个时候插手AI工作
    app_w_interrupt = workflow.compile(checkpointer=memory,
                                       interrupt_before=["action"])
    #请求工具
    config = {"configurable": {"thread_id": "4"}}
    input_message = HumanMessage(content="what is the weather in sf currently")
    for event in app_w_interrupt.stream({"messages": [input_message]},
                                        config,
                                        stream_mode="values"):
        event["messages"][-1].pretty_print()
    #获取当前节点状态以及下一个节点状态
    current_values = app_w_interrupt.get_state(config)
    print("====当前节点状态====>\n")
    print(current_values)
    print("===下一个节点状态====>\n")
    print(current_values.next)
    print("===当前的工具输入内容====>\n")
    print(current_values.values["messages"][-1].tool_calls)
    #在暂停的时候将工具输入从Agent给的指令修改为人类的
    current_values.values["messages"][-1].tool_calls[0]["args"][
        "query"] = "洛杉矶今天的天气如何？"
    #调用update_state方法，将工具输入的内容修改为人类的输入
    app_w_interrupt.update_state(config, current_values.values)
    #查看当前工作流中工具的输入值
    print("====修改后的工具输入====>\n")
    print(app_w_interrupt.get_state(config).values)
    #再次启动Agent,并从中断的节点处恢复运作，注意设置为None即是从当前开始
    print("====再次启动agent====>\n")
    for event in app_w_interrupt.stream(None, config):
        for v in event.values():
            print(v)
    #回溯整个工作流
    print("---------------回溯工作流:-------->>>>>>>>>>>>>>>>>>>>>>>>>>>>")
    for state in app_w_interrupt.get_state_history(config):
        print(state)
        print("--")
        #第二条消息
        if len(state.values["messages"]) == 2:
            to_replay = state
    print("====回溯的起点节点：====>\n")
    print(to_replay.values)
    #重播工作流
    print("---------------开始重播工作流:-------->>>>>>>>>>>>>>>>>>>>>>>>>>>>")
    for event in app_w_interrupt.stream(None, to_replay.config):
        for v in event.values():
            print(v)

    #不仅是重播，甚至可以改写过去的流向，比如提前终止工作流
    print("---------------开始分支工作流:-------->>>>>>>>>>>>>>>>>>>>>>>>>>>>")
    branch_config = app_w_interrupt.update_state(
        to_replay.config,
        {
            "messages": [
                AIMessage(content="All done here!",
                          id=to_replay.values["messages"][-1].id)
            ]
        },
    )
    branch_state = app_w_interrupt.get_state(branch_config)
    print("====分支前的节点：====>\n")
    print(branch_state.values)
    print("====运行分支后的节点：====>\n")
    print(branch_state.next)


if __name__ == "__main__":
    main()
# Out:
# <langgraph.checkpoint.memory.MemorySaver object at 0x000001C742C6C470>
# ================================ Human Message =================================
#
# hi! I'm bob
# ================================== Ai Message ==================================
#
# Hello Bob! How can I assist you today?
# {'messages': [HumanMessage(content="hi! I'm bob", additional_kwargs={}, response_metadata={}, id='c2c79786-afe7-4e85-acb7-9ee74f7d63da'), AIMessage(content='Hello Bob! How can I assist you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 149, 'total_tokens': 161}, 'model_name': 'GLM-4-Plus', 'finish_reason': 'stop'}, id='run-ffd5f222-1958-4a89-938a-b4c47a95c699-0')]}
# ()
# ================================ Human Message =================================
#
# what is the weather in sf currently
# ================================== Ai Message ==================================
# Tool Calls:
#   search (call_9062267401606679666)
#  Call ID: call_9062267401606679666
#   Args:
#     query: current weather in San Francisco
# ================================= Tool Message =================================
# Name: search
#
# ["The weather is cloudy with a chance of meatballs."]
# ================================== Ai Message ==================================
#
# The weather in San Francisco is currently cloudy with a chance of meatballs. Just kidding! That's a reference to a movie. For the actual weather, I would need to check a reliable weather service. Would you like me to do that for you?
# ************************************thread_id:4*****************************************************
# ================================ Human Message =================================
#
# what is the weather in sf currently
# ================================== Ai Message ==================================
# Tool Calls:
#   search (call_9062256337768484687)
#  Call ID: call_9062256337768484687
#   Args:
#     query: current weather in San Francisco
# ====当前节点状态====>
#
# StateSnapshot(values={'messages': [HumanMessage(content='what is the weather in sf currently', additional_kwargs={}, response_metadata={}, id='05f577c8-e218-4e92-88d4-cab15ae058e2'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query": "current weather in San Francisco"}', 'name': 'search'}, 'id': 'call_9062256337768484687', 'index': 0, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 151, 'total_tokens': 164}, 'model_name': 'GLM-4-Plus', 'finish_reason': 'tool_calls'}, id='run-611b9486-67e1-4943-bb30-50b8d3107e43-0', tool_calls=[{'name': 'search', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_9062256337768484687', 'type': 'tool_call'}])]}, next=('action',), config={'configurable': {'thread_id': '4', 'checkpoint_ns': '', 'checkpoint_id': '1ef7d80e-f7b0-6a34-8001-6724e1f95441'}}, metadata={'source': 'loop', 'writes': {'agent': {'messages': AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query": "current weather in San Francisco"}', 'name': 'search'}, 'id': 'call_9062256337768484687', 'index': 0, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 151, 'total_tokens': 164}, 'model_name': 'GLM-4-Plus', 'finish_reason': 'tool_calls'}, id='run-611b9486-67e1-4943-bb30-50b8d3107e43-0', tool_calls=[{'name': 'search', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_9062256337768484687', 'type': 'tool_call'}])}}, 'step': 1, 'parents': {}}, created_at='2024-09-28T10:03:39.886877+00:00', parent_config={'configurable': {'thread_id': '4', 'checkpoint_ns': '', 'checkpoint_id': '1ef7d80e-ebb5-6397-8000-b794b10db53c'}}, tasks=(PregelTask(id='19321e5f-4e79-0c2f-9fb7-92fc30481cf5', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None),))
# ===下一个节点状态====>
#
# ('action',)
# ===当前的工具输入内容====>
#
# [{'name': 'search', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_9062256337768484687', 'type': 'tool_call'}]
# ====修改后的工具输入====>
#
# {'messages': [HumanMessage(content='what is the weather in sf currently', additional_kwargs={}, response_metadata={}, id='05f577c8-e218-4e92-88d4-cab15ae058e2'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query": "current weather in San Francisco"}', 'name': 'search'}, 'id': 'call_9062256337768484687', 'index': 0, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 151, 'total_tokens': 164}, 'model_name': 'GLM-4-Plus', 'finish_reason': 'tool_calls'}, id='run-611b9486-67e1-4943-bb30-50b8d3107e43-0', tool_calls=[{'name': 'search', 'args': {'query': '洛杉矶今天的天气如何？'}, 'id': 'call_9062256337768484687', 'type': 'tool_call'}])]}
# ====再次启动agent====>
#
# {'messages': [ToolMessage(content='["The weather is cloudy with a chance of meatballs."]', name='search', id='5e57de49-c905-462d-8d61-1164fa037c86', tool_call_id='call_9062256337768484687')]}
# {'messages': AIMessage(content='The weather in San Francisco is currently cloudy with a chance of meatballs.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 167, 'total_tokens': 184}, 'model_name': 'GLM-4-Plus', 'finish_reason': 'stop'}, id='run-dff36b92-c826-4f4c-a0df-c066cd031373-0')}
# ---------------回溯工作流:-------->>>>>>>>>>>>>>>>>>>>>>>>>>>>
# StateSnapshot(values={'messages': [HumanMessage(content='what is the weather in sf currently', additional_kwargs={}, response_metadata={}, id='05f577c8-e218-4e92-88d4-cab15ae058e2'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query": "current weather in San Francisco"}', 'name': 'search'}, 'id': 'call_9062256337768484687', 'index': 0, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 151, 'total_tokens': 164}, 'model_name': 'GLM-4-Plus', 'finish_reason': 'tool_calls'}, id='run-611b9486-67e1-4943-bb30-50b8d3107e43-0', tool_calls=[{'name': 'search', 'args': {'query': '洛杉矶今天的天气如何？'}, 'id': 'call_9062256337768484687', 'type': 'tool_call'}]), ToolMessage(content='["The weather is cloudy with a chance of meatballs."]', name='search', id='5e57de49-c905-462d-8d61-1164fa037c86', tool_call_id='call_9062256337768484687'), AIMessage(content='The weather in San Francisco is currently cloudy with a chance of meatballs.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 167, 'total_tokens': 184}, 'model_name': 'GLM-4-Plus', 'finish_reason': 'stop'}, id='run-dff36b92-c826-4f4c-a0df-c066cd031373-0')]}, next=(), config={'configurable': {'thread_id': '4', 'checkpoint_ns': '', 'checkpoint_id': '1ef7d80f-064a-6239-8004-364a41cb4dfe'}}, metadata={'source': 'loop', 'writes': {'agent': {'messages': AIMessage(content='The weather in San Francisco is currently cloudy with a chance of meatballs.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 167, 'total_tokens': 184}, 'model_name': 'GLM-4-Plus', 'finish_reason': 'stop'}, id='run-dff36b92-c826-4f4c-a0df-c066cd031373-0')}}, 'step': 4, 'parents': {}}, created_at='2024-09-28T10:03:41.418757+00:00', parent_config={'configurable': {'thread_id': '4', 'checkpoint_ns': '', 'checkpoint_id': '1ef7d80e-f7f5-601d-8003-ce0b3f062274'}}, tasks=())
# --
# StateSnapshot(values={'messages': [HumanMessage(content='what is the weather in sf currently', additional_kwargs={}, response_metadata={}, id='05f577c8-e218-4e92-88d4-cab15ae058e2'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query": "current weather in San Francisco"}', 'name': 'search'}, 'id': 'call_9062256337768484687', 'index': 0, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 151, 'total_tokens': 164}, 'model_name': 'GLM-4-Plus', 'finish_reason': 'tool_calls'}, id='run-611b9486-67e1-4943-bb30-50b8d3107e43-0', tool_calls=[{'name': 'search', 'args': {'query': '洛杉矶今天的天气如何？'}, 'id': 'call_9062256337768484687', 'type': 'tool_call'}]), ToolMessage(content='["The weather is cloudy with a chance of meatballs."]', name='search', id='5e57de49-c905-462d-8d61-1164fa037c86', tool_call_id='call_9062256337768484687')]}, next=('agent',), config={'configurable': {'thread_id': '4', 'checkpoint_ns': '', 'checkpoint_id': '1ef7d80e-f7f5-601d-8003-ce0b3f062274'}}, metadata={'source': 'loop', 'writes': {'action': {'messages': [ToolMessage(content='["The weather is cloudy with a chance of meatballs."]', name='search', id='5e57de49-c905-462d-8d61-1164fa037c86', tool_call_id='call_9062256337768484687')]}}, 'step': 3, 'parents': {}}, created_at='2024-09-28T10:03:39.915881+00:00', parent_config={'configurable': {'thread_id': '4', 'checkpoint_ns': '', 'checkpoint_id': '1ef7d80e-f7d5-6443-8002-cdef91a394ee'}}, tasks=(PregelTask(id='0746cb54-1d96-151a-9404-a3ffc2d21330', name='agent', path=('__pregel_pull', 'agent'), error=None, interrupts=(), state=None),))
# --
# StateSnapshot(values={'messages': [HumanMessage(content='what is the weather in sf currently', additional_kwargs={}, response_metadata={}, id='05f577c8-e218-4e92-88d4-cab15ae058e2'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query": "current weather in San Francisco"}', 'name': 'search'}, 'id': 'call_9062256337768484687', 'index': 0, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 151, 'total_tokens': 164}, 'model_name': 'GLM-4-Plus', 'finish_reason': 'tool_calls'}, id='run-611b9486-67e1-4943-bb30-50b8d3107e43-0', tool_calls=[{'name': 'search', 'args': {'query': '洛杉矶今天的天气如何？'}, 'id': 'call_9062256337768484687', 'type': 'tool_call'}])]}, next=('action',), config={'configurable': {'thread_id': '4', 'checkpoint_ns': '', 'checkpoint_id': '1ef7d80e-f7d5-6443-8002-cdef91a394ee'}}, metadata={'source': 'update', 'step': 2, 'writes': {'agent': {'messages': [HumanMessage(content='what is the weather in sf currently', additional_kwargs={}, response_metadata={}, id='05f577c8-e218-4e92-88d4-cab15ae058e2'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query": "current weather in San Francisco"}', 'name': 'search'}, 'id': 'call_9062256337768484687', 'index': 0, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 151, 'total_tokens': 164}, 'model_name': 'GLM-4-Plus', 'finish_reason': 'tool_calls'}, id='run-611b9486-67e1-4943-bb30-50b8d3107e43-0', tool_calls=[{'name': 'search', 'args': {'query': '洛杉矶今天的天气如何？'}, 'id': 'call_9062256337768484687', 'type': 'tool_call'}])]}}, 'parents': {}}, created_at='2024-09-28T10:03:39.902880+00:00', parent_config={'configurable': {'thread_id': '4', 'checkpoint_ns': '', 'checkpoint_id': '1ef7d80e-f7b0-6a34-8001-6724e1f95441'}}, tasks=(PregelTask(id='d1a884db-0f1f-0070-618e-32a9f49789dc', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None),))
# --
# StateSnapshot(values={'messages': [HumanMessage(content='what is the weather in sf currently', additional_kwargs={}, response_metadata={}, id='05f577c8-e218-4e92-88d4-cab15ae058e2'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query": "current weather in San Francisco"}', 'name': 'search'}, 'id': 'call_9062256337768484687', 'index': 0, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 151, 'total_tokens': 164}, 'model_name': 'GLM-4-Plus', 'finish_reason': 'tool_calls'}, id='run-611b9486-67e1-4943-bb30-50b8d3107e43-0', tool_calls=[{'name': 'search', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_9062256337768484687', 'type': 'tool_call'}])]}, next=('action',), config={'configurable': {'thread_id': '4', 'checkpoint_ns': '', 'checkpoint_id': '1ef7d80e-f7b0-6a34-8001-6724e1f95441'}}, metadata={'source': 'loop', 'writes': {'agent': {'messages': AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query": "current weather in San Francisco"}', 'name': 'search'}, 'id': 'call_9062256337768484687', 'index': 0, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 151, 'total_tokens': 164}, 'model_name': 'GLM-4-Plus', 'finish_reason': 'tool_calls'}, id='run-611b9486-67e1-4943-bb30-50b8d3107e43-0', tool_calls=[{'name': 'search', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_9062256337768484687', 'type': 'tool_call'}])}}, 'step': 1, 'parents': {}}, created_at='2024-09-28T10:03:39.886877+00:00', parent_config={'configurable': {'thread_id': '4', 'checkpoint_ns': '', 'checkpoint_id': '1ef7d80e-ebb5-6397-8000-b794b10db53c'}}, tasks=(PregelTask(id='19321e5f-4e79-0c2f-9fb7-92fc30481cf5', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None),))
# --
# StateSnapshot(values={'messages': [HumanMessage(content='what is the weather in sf currently', additional_kwargs={}, response_metadata={}, id='05f577c8-e218-4e92-88d4-cab15ae058e2')]}, next=('agent',), config={'configurable': {'thread_id': '4', 'checkpoint_ns': '', 'checkpoint_id': '1ef7d80e-ebb5-6397-8000-b794b10db53c'}}, metadata={'source': 'loop', 'writes': None, 'step': 0, 'parents': {}}, created_at='2024-09-28T10:03:38.630923+00:00', parent_config={'configurable': {'thread_id': '4', 'checkpoint_ns': '', 'checkpoint_id': '1ef7d80e-ebb2-670b-bfff-5d845841ed20'}}, tasks=(PregelTask(id='a4401660-e57c-f9ba-bf79-0acde7700f1c', name='agent', path=('__pregel_pull', 'agent'), error=None, interrupts=(), state=None),))
# --
# StateSnapshot(values={'messages': []}, next=('__start__',), config={'configurable': {'thread_id': '4', 'checkpoint_ns': '', 'checkpoint_id': '1ef7d80e-ebb2-670b-bfff-5d845841ed20'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [HumanMessage(content='what is the weather in sf currently', additional_kwargs={}, response_metadata={})]}}, 'step': -1, 'parents': {}}, created_at='2024-09-28T10:03:38.630324+00:00', parent_config=None, tasks=(PregelTask(id='5932450b-2e62-d7ba-6bd5-0cc53a31f6b4', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None),))
# --
# ====回溯的起点节点：====>
#
# {'messages': [HumanMessage(content='what is the weather in sf currently', additional_kwargs={}, response_metadata={}, id='05f577c8-e218-4e92-88d4-cab15ae058e2'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query": "current weather in San Francisco"}', 'name': 'search'}, 'id': 'call_9062256337768484687', 'index': 0, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 151, 'total_tokens': 164}, 'model_name': 'GLM-4-Plus', 'finish_reason': 'tool_calls'}, id='run-611b9486-67e1-4943-bb30-50b8d3107e43-0', tool_calls=[{'name': 'search', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_9062256337768484687', 'type': 'tool_call'}])]}
# ---------------开始重播工作流:-------->>>>>>>>>>>>>>>>>>>>>>>>>>>>
# {'messages': [ToolMessage(content='["The weather is cloudy with a chance of meatballs."]', name='search', id='9c65a512-d817-486d-b8bd-cb1d89f682f8', tool_call_id='call_9062256337768484687')]}
# {'messages': AIMessage(content='The weather in San Francisco is currently cloudy with a chance of meatballs.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 167, 'total_tokens': 184}, 'model_name': 'GLM-4-Plus', 'finish_reason': 'stop'}, id='run-f01bc345-1c4d-48c8-b85f-529a45d2fd72-0')}
# ---------------开始分支工作流:-------->>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ====分支前的节点：====>
#
# {'messages': [HumanMessage(content='what is the weather in sf currently', additional_kwargs={}, response_metadata={}, id='05f577c8-e218-4e92-88d4-cab15ae058e2'), AIMessage(content='All done here!', additional_kwargs={}, response_metadata={}, id='run-611b9486-67e1-4943-bb30-50b8d3107e43-0')]}
# ====运行分支后的节点：====>
#
# ()
